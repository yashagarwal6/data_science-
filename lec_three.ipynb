# %% [markdown]
# <a href="https://colab.research.google.com/github/yashagarwal6/data_science-/blob/main/lec_three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#finctions can be used to perform tasks , pre coded
def fun_name(parameters):
  #body of the function

# %%
 def addition(a,b):
  print(a+b) #adding two numbers by using functions

 addition(4,6)
# Out:
# 10

# %%
#lambda function
x = lambda a,b : b * a
print(x(2,4))
# Out:
# 8

# %%
st = ""
print(len(st))

st = " yash agrawal"
st1 = st.upper() #uppercase
print(st1)

st2 = st.lower() #lowercase
print(st2)

st3 = st.capitalize() #capitalzize
print(st3)

st4 = st.title() #title capital
print(st4)

st5 = st.strip() # strip remove the first space
print(st5)
# Out:
# 0
#  YASH AGRAWAL
#  yash agrawal
#  yash agrawal
#  Yash Agrawal
# yash agrawal

# %%
a = "today, "
b = "    weather    "
c = "is GooD"
a = a.capitalize()
b = b.strip()
c = c.lower()
c = c.replace("good","bad")
d = a+b+" "+c
print(d)
x = d.find("bad")
print(x)
#in find , if not find then return -1 , in index(), it gives error
# Out:
# Today, weather is bad
# 18

# %%
#lc 125 ;
s = "A man, a plan, a canal: Panama"
ans = ""
for i in s:
  if('a'<=i<='z') or ('A'<=i<='Z') or ('0'<=i<='9'):
    ans = i.lower() + ans

if ans == ans[::-1]:
  print("true")
# Out:
# true

# %%
s = "hello world"

print(s[-5])
print(s[6 : 11]) # aceess substring using this way
# Out:
# w
# world

# %%
#explore all functions of sets
st = {2,2,23,2,1}

print(st)
# Out:
# {1, 2, 23}

# %%
dct = {
    "name": ["Ramesh","Suresh","mohan","madan"],
    "age": 23,
    "occupation": "student",
    "class": 10,
    "roll no": 92,
}
print(dct['name'])
print(dct['name'][0])
print(dct)
# Out:
# ['Ramesh', 'Suresh', 'mohan', 'madan']
# Ramesh
# {'name': ['Ramesh', 'Suresh', 'mohan', 'madan'], 'age': 23, 'occupation': 'student', 'class': 10, 'roll no': 92}
