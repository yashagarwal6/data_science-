# %% [markdown]
# <a href="https://colab.research.google.com/github/yashagarwal6/data_science-/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dct = {
    'name' : ['Tom','Nick','Krish','Jack'],
    'age' : [20,21,19,18],
    'roll' : [1,2,3,4]
}
#complete structure is dataframe
#display function is used to print datadframes instead of print


df=pd.DataFrame(dct, index = ['A','B','C','D']) #WE CAN EDIT index
display(df)
# Out:
#     name  age  roll
# A    Tom   20     1
# B   Nick   21     2
# C  Krish   19     3
# D   Jack   18     4

# %%
df = pd.read_csv('student_data.csv')#file path
# df.tail(3) #from last just like head
# df.shape #provides the shape of data , columns and rows
#metadata is the data of data
# df.info()
# df.describe() #statistical summary
# df['internet_usage'] #for particular column
# df[['study_hours','internet_usage']]

# df.iloc[0: 5] #5 is no. of rows
# df.loc[df['study_hours']==11],['study_hours']
# df.loc[df['study_hours']==11,['study_hours','sleep_hours']]
df.loc[df['study_hours']==11,['study_hours','sleep_hours']].iloc[4: 8] #with range
# Out:
# (      study_hours  attendance  sleep_hours  internet_usage  \
#  2              11          60            7               6
#  9              11          77            4               9
#  10             11          64            8               8
#  29             11          63            9              10
#  30             11          45            5               2
#  ...           ...         ...          ...             ...
#  9969           11          84            8               2
#  9971           11          81            9               6
#  9978           11          92            8               2
#  9979           11          78            9               5
#  9988           11          94            6               9
#
#        assignments_completed  previous_score  exam_score placement_status
#  2                        10              45      100.00           Placed
#  9                        15              69      100.00           Placed
# ...

# %%
df = pd.read_csv('student_data.csv')
# df.loc[df['assignments_completed']==8].iloc[1]
# df[df["assignments_completed"] > 3]
df.rename(columns = {'assignments_completed': 'assign_completed'},inplace = True)
df.dropna()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
import pandas as pd
dct = {'name' : ['Tom','Nick','Krish','Jack'],
    'age' : [20,None,19,18],
    'roll' : [1,2,3,None]
}
df=pd.DataFrame(dct)
df.dropna()
# Out:
#     name   age  roll
# 0    Tom  20.0   1.0
# 2  Krish  19.0   3.0
